# %% [markdown]
# ## Yahoo-Finance-Options
#
# This notebook downloads option data from Yahoo Finance using the yahoo_fin package.
#
# We pick out a single case to compare the actual price on the market against the price predicted by Black-Scholes using volatility derived from returns on the underlying stock and a rate taken from the US Treasury.

# %%
#http://theautomatic.net/2019/04/17/how-to-get-options-data-with-python/
#https://algotrading101.com/learn/yahoo-finance-api-guide/
from yahoo_fin import options
import pandas as pd

# %%
ticker="nflx" # Netflix: change this to try out any other stocks available on Yahoo Finance

call_dates= options.get_expiration_dates(ticker)
call_dates
# Out:
# ['September 25, 2020',
#  'October 2, 2020',
#  'October 9, 2020',
#  'October 16, 2020',
#  'October 23, 2020',
#  'October 30, 2020',
#  'November 20, 2020',
#  'December 18, 2020',
#  'January 15, 2021',
#  'February 19, 2021',
#  'March 19, 2021',
#  'June 18, 2021',
#  'July 16, 2021',
#  'September 17, 2021',
#  'January 21, 2022',
#  'June 17, 2022',
#  'January 20, 2023']

# %%
import datetime
today = datetime.date.today()
#maturity = datetime.date(2020, 10, 23)    # Y M D
maturity = datetime.date(2021, 3, 19)    # Y M D
daycount = (maturity - today).days
print('maturity ',maturity,'    daycount ',daycount)


calls=options.get_calls("nflx", maturity)
calls["Volume"]=pd.to_numeric(calls["Volume"],errors='coerce') # coerce replaces - with NaN
calls[calls.Volume>10]
# Out:
# maturity  2021-03-19     daycount  178
#           Contract Name         Last Trade Date  Strike  Last Price    Bid  \
# 15  NFLX210319C00425000  2020-09-11 12:48PM EDT   425.0       94.95  91.35
# 18  NFLX210319C00440000   2020-09-11 1:00PM EDT   440.0       86.35  82.55
# 19  NFLX210319C00445000   2020-09-11 1:00PM EDT   445.0       83.35  79.70
# 21  NFLX210319C00455000   2020-09-11 1:00PM EDT   455.0       78.30  74.30
# 22  NFLX210319C00460000   2020-09-18 3:46PM EDT   460.0       64.80  71.80
# 24  NFLX210319C00470000   2020-09-21 3:18PM EDT   470.0       69.25  66.80
# 26  NFLX210319C00480000   2020-09-21 1:44PM EDT   480.0       65.17  63.25
# 28  NFLX210319C00490000   2020-09-17 1:25PM EDT   490.0       52.80  57.65
# 30  NFLX210319C00500000   2020-09-21 3:49PM EDT   500.0       56.72  53.10
# 39  NFLX210319C00545000  2020-09-16 12:29PM EDT   545.0       44.90  37.55
# 44  NFLX210319C00570000  2020-09-15 12:28PM EDT   570.0       39.00  30.50
# 45  NFLX210319C00575000   2020-09-09 3:24PM EDT   575.0       29.00  29.25
# 50  NFLX210319C00600000  2020-09-21 10:53AM EDT   600.0       22.60  23.95
# 57  NFLX210319C00680000   2020-09-08 1:18PM EDT   680.0       15.30  12.10
# 58  NFLX210319C00700000   2020-09-21 3:46PM EDT   700.0       11.73  10.60
# 59  NFLX210319C00720000   2020-09-21 3:34PM EDT   720.0        9.80   8.95
# 64  NFLX210319C00820000   2020-09-21 1:42PM EDT   820.0        4.95   4.50
#
#       Ask  Change % Change  Volume  Open Interest Implied Volatility
# 15  93.20    0.00        -    15.0             16             47.71%
# 18  85.60    0.00        -    20.0              0             48.41%
# 19  82.25    0.00        -    15.0             15             47.86%
# 21  77.30    0.00        -    16.0             17             48.03%
# 22  74.65    0.00        -    11.0              0             47.90%
# 24  69.50    0.00        -    16.0              0             47.61%
# 26  64.50    2.17   +3.44%    20.0            153             47.25%
# 28  60.00    0.00        -    25.0             60             47.09%
# 30  56.00    0.00        -    18.0            272             47.12%
# 39  39.60    0.00        -    27.0             29             46.39%
# 44  32.75    0.00        -    70.0             76             46.35%
# 45  31.30    0.00        -    11.0              0             46.17%
# 50  25.70    0.00        -    12.0             55             46.10%
# 57  13.50    0.00        -    14.0             35             46.06%
# 58  11.65    0.00        -    35.0            215             46.29%
# 59  10.00    0.00        -    24.0              0             46.44%
# 64   5.00    0.00        -    17.0             95             47.75%

# %%
mystrike=570
mycall=calls[calls.Strike == mystrike]
mycall
# Out:
#           Contract Name         Last Trade Date  Strike  Last Price   Bid  \
# 44  NFLX210319C00570000  2020-09-15 12:28PM EDT   570.0        39.0  30.5
#
#       Ask  Change % Change  Volume  Open Interest Implied Volatility
# 44  32.75     0.0        -    70.0             76             46.35%

# %%
myprice=float(0.5*(mycall["Bid"]+mycall["Ask"]))
print("Maturity in",daycount,"days", "Strike", mystrike, "Price",myprice)
# Out:
# Maturity in 180 days Strike 570 Price 28.875
